# %%
import scanpy as sc
import pickle
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
adata=sc.read_h5ad("/gladstone/engelhardt/pelka-collaboration/HuColonCa-FFPE-ImmuOnco-LH_VMSC02001_20220427/HuColonCa-FFPE-ImmuOnco-LH_VMSC02001_20220427/vizgen_public_midlevel_annotated.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 754866 × 500
#     obs: 'cell', 'n_genes_by_counts', 'total_counts', 'n_counts', 'cell_type', 'kmeans11_anno', 'kmeans11', 'midlevel_type'
#     var: 'gene', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'mean', 'std'
#     uns: 'kmeans11_colors', 'kmeans12_colors', 'kmeans13_colors', 'kmeans14_colors', 'kmeans15_colors', 'kmeans16_colors', 'kmeans17_colors', 'log1p', 'neighbors', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
cell = adata.obs['midlevel_type']
df = pd.DataFrame(cell)
df.to_csv('data/midleveltype_LH.csv')

# %%
kmean = adata.obs['kmeans11_anno']
df = pd.DataFrame(kmean)
df.to_csv('kmean_anno_sample1.csv')

# %%
spatial=adata.obsm['spatial']
spatial[:,1] = -spatial[:,1]
df = pd.DataFrame(spatial)
df.to_csv('data/spatial_sample1.csv')

# %%
colors = adata.uns['kmeans11_colors']
colors = np.append(colors, "red")
colors
# Out:
# array(['#1f77b4', '#ff7f0e', '#279e68', '#d62728', '#aa40fc', '#8c564b',
#        '#e377c2', '#b5bd61', '#17becf', '#aec7e8', '#ffbb78', 'red'],
#       dtype=object)

# %%
# create map from global type to color
color_map = dict(zip(kmean.cat.categories,colors))

# %%
plt.subplots()
plt.scatter(x=spatial[:,0], y=spatial[:,1], c=kmean.map(color_map), s = 0.2)
plt.legend(markerscale = 10, loc='upper right', bbox_to_anchor=(0.5, 0.5))
#ax.xticks([])
#ax.yticks([])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Error in callback <function _draw_all_if_interactive at 0x7f64fef17ba0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/miniconda3/envs/def/lib/python3.11/site-packages/matplotlib/pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~/miniconda3/envs/def/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# ...

# %%
adata=sc.read_h5ad("/gladstone/engelhardt/pelka-collaboration/HuColonCa-FFPE-ImmuOnco-LH_VMSC02001_20220427/HuColonCa-FFPE-ImmuOnco-LH_VMSC02001_20220427/baysor_20231207/20231212_public_singlecells_n16_baysor_geneformer_annos_kmeans15_nhoods.h5ad")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 adata=sc.read_h5ad("/gladstone/engelhardt/pelka-collaboration/HuColonCa-FFPE-ImmuOnco-LH_VMSC02001_20220427/HuColonCa-FFPE-ImmuOnco-LH_VMSC02001_20220427/baysor_20231207/20231212_public_singlecells_n16_baysor_geneformer_annos_kmeans15_nhoods.h5ad")
#
# File ~/miniconda3/envs/def/lib/python3.11/site-packages/anndata/_io/h5ad.py:230, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     222         raise NotImplementedError(
#     223             "Currently only `X` and `raw/X` can be read as sparse."
#     224         )
#     226 rdasp = partial(
#     227     read_dense_as_sparse, sparse_format=as_sparse_fmt, axis_chunk=chunk_size
#     228 )
# --> 230 with h5py.File(filename, "r") as f:
#     232     def callback(func, elem_name: str, elem, iospec):
# ...
